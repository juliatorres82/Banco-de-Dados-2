# %%
import pandas as pd
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine, text
from sshtunnel import SSHTunnelForwarder

#EDITAR AQUI PARA O CAMINHO DAS BASES DE DADOS -- ou fzr automatico
CAMINHO_BASES = 'C:/utfpr/bd2/Banco-de-Dados-2/Datasets'

################## DF 1: Beneficiários do Programa Bolsa Família por faixa de renda (PR) ##################
df_renda_1 = pd.read_csv(f'{CAMINHO_BASES}/Pessoas_PBF_Renda_ateFev2023.csv', sep=',', encoding='latin1')

# Index(['Código', 'Unidade Territorial', 'UF', 'Referência',
#        'Quantidade de pessoas em famílias  em situação de extrema pobreza beneficiárias do Programa Bolsa Família',
#        'Quantidade de pessoas em famílias  em situação de pobreza beneficiárias do Programa Bolsa Família',
#        'Quantidade de pessoas em famílias de baixa renda** beneficiárias do Programa Bolsa Família'],
#       dtype='str')

df_renda_1 = df_renda_1.drop(columns=['Código', 'UF'])
df_renda_1 = df_renda_1.rename(columns={'Referência':'Data', 'Unidade Territorial':'Municipio',
                                    'Quantidade de pessoas em famílias  em situação de extrema pobreza beneficiárias do Programa Bolsa Família':'Pessoas beneficiarias BF em extrema pobreza',
                                    'Quantidade de pessoas em famílias  em situação de pobreza beneficiárias do Programa Bolsa Família':'Pessoas beneficiarias BF em pobreza',
                                    'Quantidade de pessoas em famílias de baixa renda** beneficiárias do Programa Bolsa Família':'Pessoas beneficiarias BF em baixa renda'})

print(df_renda_1.columns)
# Out:
# Index(['Municipio', 'Data', 'Pessoas beneficiarias BF em extrema pobreza',
#        'Pessoas beneficiarias BF em pobreza',
#        'Pessoas beneficiarias BF em baixa renda'],
#       dtype='str')

# %%
df_renda_2 = pd.read_csv(f'{CAMINHO_BASES}/Pessoas_PBF_Renda_dpsMar2023.csv', sep=',', encoding='latin1')

df_renda_2 = df_renda_2.drop(columns=['Código', 'UF'])

# Index(['Unidade Territorial', 'UF', 'Referência',
#        'Quantidade de pessoas em famílias beneficiárias do Programa Bolsa Família em situação de pobreza, segundo a faixa do Programa*',
#        'Quantidade de pessoas em famílias de baixa renda** beneficiárias do Programa Bolsa Família',
#        'Quantidade de pessoas em famílias com renda per capita mensal acima de meio salário-mínimo*** beneficiárias do Programa Bolsa Família'],
#       dtype='str')

df_renda_2 = df_renda_2.rename(columns={'Referência':'Data', 'Unidade Territorial':'Municipio',
                                    'Quantidade de pessoas em famílias beneficiárias do Programa Bolsa Família em situação de pobreza, segundo a faixa do Programa*':'Pessoas beneficiarias BF em pobreza',
                                    'Quantidade de pessoas em famílias de baixa renda** beneficiárias do Programa Bolsa Família':'Pessoas beneficiarias BF em baixa renda',
                                    'Quantidade de pessoas em famílias com renda per capita mensal acima de meio salário-mínimo*** beneficiárias do Programa Bolsa Família':'Pessoas beneficiarias BF renda per capita maior meio salario minimo'})

print(df_renda_2.columns)
# Out:
# Index(['Municipio', 'Data', 'Pessoas beneficiarias BF em pobreza',
#        'Pessoas beneficiarias BF em baixa renda',
#        'Pessoas beneficiarias BF renda per capita maior meio salario minimo'],
#       dtype='str')

# %%
df_renda_final = pd.concat([df_renda_1, df_renda_2], ignore_index=True)
df_renda_final

# df_renda_final.to_csv(f'{CAMINHO_BASES}/Tabela_PBF_PANDAS.csv', index=False, encoding='utf-8')
# Out:
#       Municipio     Data  Pessoas beneficiarias BF em extrema pobreza  \
# 0        ABATIÁ  02/2023                                        589.0
# 1        ABATIÁ  01/2023                                        596.0
# 2        ABATIÁ  05/2022                                        615.0
# 3        ABATIÁ  09/2022                                        584.0
# 4        ABATIÁ  06/2022                                        597.0
# ...         ...      ...                                          ...
# 29920    XAMBRÊ  02/2026                                          NaN
# 29921    XAMBRÊ  03/2026                                          NaN
# 29922    XAMBRÊ  04/2026                                          NaN
# 29923    XAMBRÊ  05/2026                                          NaN
# 29924    XAMBRÊ  06/2026                                          NaN
#
#        Pessoas beneficiarias BF em pobreza  \
# 0                                      583
# 1                                      586
# 2                                      595
# 3                                      567
# 4                                      602
# ...                                    ...
# 29920                                  970
# 29921                                  980
# 29922                                 1011
# 29923                                 1045
# 29924                                 1088
#
#        Pessoas beneficiarias BF em baixa renda  \
# 0                                          271
# 1                                          271
# 2                                          162
# 3                                          251
# 4                                          180
# ...                                        ...
# 29920                                      206
# 29921                                      191
# 29922                                      223
# 29923                                      202
# 29924                                      201
#
#        Pessoas beneficiarias BF renda per capita maior meio salario minimo
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 29920                                                0.0
# 29921                                                0.0
# 29922                                                0.0
# 29923                                                0.0
# 29924                                                0.0
#
# [29925 rows x 6 columns]

# %%
import pandas as pd
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine, text
from sshtunnel import SSHTunnelForwarder

#EDITAR AQUI PARA O CAMINHO DAS BASES DE DADOS -- ou fzr automatico
CAMINHO_BASES = 'C:/utfpr/bd2/Banco-de-Dados-2/Datasets'

################## DF 1: Beneficiários do Programa Bolsa Família por faixa de renda (PR) ##################
dfFem_faixaEtaria = pd.read_csv(f'{CAMINHO_BASES}/PessoasFem_PBF_faixaEtaria.csv', sep=',', encoding='latin1')

# Index(['Código', 'Unidade Territorial', 'UF', 'Referência',
#        'Quantidade de pessoas do sexo feminino com idade entre 0 e 3 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único',
#        'Quantidade de pessoas do sexo feminino com idade entre 4 e 6 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único',
#        'Quantidade de pessoas do sexo feminino com idade entre 7 e 15 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único',
#        'Quantidade de pessoas do sexo feminino com idade entre 16 e 17 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único',
#        'Quantidade de pessoas do sexo feminino com idade entre 18 e 24 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único',
#        'Quantidade de pessoas do sexo feminino com idade entre 25 e 34 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único',
#        'Quantidade de pessoas do sexo feminino com idade entre 35 e 39 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único',
#        'Quantidade de pessoas do sexo feminino com idade entre 40 e 44 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único',
#        'Quantidade de pessoas do sexo feminino com idade entre 45 e 49 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único',
#        'Quantidade de pessoas do sexo feminino com idade entre 50 e 54 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único',
#        'Quantidade de pessoas do sexo feminino com idade entre 55 e 59 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único',
#        'Quantidade de pessoas do sexo feminino com idade entre 60 e 64 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único',
#        'Quantidade de pessoas do sexo feminino com idade acima de 64 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único'],
#       dtype='str')

dfFem_faixaEtaria = dfFem_faixaEtaria.rename(columns={'Referência':'Data', 'Unidade Territorial':'Municipio',
                                                    'Quantidade de pessoas do sexo feminino com idade entre 0 e 3 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único':'Beneficiarias BF feminino 0 a 3 anos',
                                                    'Quantidade de pessoas do sexo feminino com idade entre 4 e 6 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único':'Beneficiarias BF feminino 4 a 6 anos',
                                                    'Quantidade de pessoas do sexo feminino com idade entre 7 e 15 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único':'Beneficiarias BF feminino 7 a 15 anos',
                                                    'Quantidade de pessoas do sexo feminino com idade entre 16 e 17 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único': 'Beneficiarias BF feminino 16 a 17 anos',
                                                    'Quantidade de pessoas do sexo feminino com idade entre 18 e 24 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único': 'Beneficiarias BF feminino 18 a 24 anos',
                                                    'Quantidade de pessoas do sexo feminino com idade entre 25 e 34 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único': 'Beneficiarias BF feminino 25 a 34 anos',
                                                    'Quantidade de pessoas do sexo feminino com idade entre 35 e 39 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único': 'Beneficiarias BF feminino 35 a 39 anos',
                                                    'Quantidade de pessoas do sexo feminino com idade entre 40 e 44 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único': 'Beneficiarias BF feminino 40 a 44 anos',
                                                    'Quantidade de pessoas do sexo feminino com idade entre 45 e 49 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único': 'Beneficiarias BF feminino 45 a 49 anos',
                                                    'Quantidade de pessoas do sexo feminino com idade entre 50 e 54 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único': 'Beneficiarias BF feminino 50 a 54 anos',
                                                    'Quantidade de pessoas do sexo feminino com idade entre 55 e 59 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único': 'Beneficiarias BF feminino 55 a 59 anos',
                                                    'Quantidade de pessoas do sexo feminino com idade entre 60 e 64 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único': 'Beneficiarias BF feminino 60 a 64 anos',
                                                    'Quantidade de pessoas do sexo feminino com idade acima de 64 anos beneficiárias do Programa Bolsa Família inscritas no Cadastro Único': 'Beneficiarias BF feminino acima de 64 anos'})

dfFem_faixaEtaria = dfFem_faixaEtaria.drop(columns=['Código', 'UF'])

df_renda = pd.concat([df_renda_1, df_renda_2], ignore_index=True)
df_teste = pd.merge(df_renda, dfFem_faixaEtaria, on=['Data', 'Municipio'], how='outer')
df_teste.to_csv(f'{CAMINHO_BASES}/Tabela_TESTEE_PANDAS.csv', index=False, encoding='utf-8')
df_teste
# Out:
#                  Municipio     Data  \
# 0                   ABATIÁ  01/2015
# 1             ADRIANÓPOLIS  01/2015
# 2            AGUDOS DO SUL  01/2015
# 3      ALMIRANTE TAMANDARÉ  01/2015
# 4       ALTAMIRA DO PARANÁ  01/2015
# ...                    ...      ...
# 56254              VIRMOND  12/2025
# 56255             VITORINO  12/2025
# 56256       WENCESLAU BRAZ  12/2025
# 56257               XAMBRÊ  12/2025
# 56258               ÂNGULO  12/2025
#
#        Pessoas beneficiarias BF em extrema pobreza  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 56254                                          NaN
# 56255                                          NaN
# 56256                                          NaN
# 56257                                          NaN
# 56258                                          NaN
#
#        Pessoas beneficiarias BF em pobreza  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 56254                                386.0
# 56255                               1135.0
# 56256                               3489.0
# 56257                               1000.0
# 56258                                311.0
#
#        Pessoas beneficiarias BF em baixa renda  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 56254                                    170.0
# 56255                                    224.0
# 56256                                    611.0
# 56257                                    195.0
# 56258                                     97.0
#
#        Pessoas beneficiarias BF renda per capita maior meio salario minimo  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 56254                                                0.0
# 56255                                                0.0
# 56256                                                0.0
# 56257                                                0.0
# 56258                                                0.0
#
#        Beneficiarias BF feminino 0 a 3 anos  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 56254                                  31.0
# 56255                                  92.0
# 56256                                 220.0
# 56257                                  73.0
# 56258                                  14.0
#
#        Beneficiarias BF feminino 4 a 6 anos  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 56254                                  24.0
# 56255                                  66.0
# 56256                                 174.0
# 56257                                  61.0
# 56258                                  22.0
#
#        Beneficiarias BF feminino 7 a 15 anos  \
# 0                                      253.0
# 1                                      267.0
# 2                                      267.0
# 3                                     1961.0
# 4                                      118.0
# ...                                      ...
# 56254                                   60.0
# 56255                                  166.0
# 56256                                  427.0
# 56257                                  119.0
# 56258                                   51.0
#
#        Beneficiarias BF feminino 16 a 17 anos  \
# 0                                        75.0
# 1                                        40.0
# 2                                        55.0
# 3                                       379.0
# 4                                        27.0
# ...                                       ...
# 56254                                    10.0
# 56255                                    22.0
# 56256                                    83.0
# 56257                                    15.0
# 56258                                    10.0
#
#        Beneficiarias BF feminino 18 a 24 anos  \
# 0                                       146.0
# 1                                       101.0
# 2                                       135.0
# 3                                       844.0
# 4                                        61.0
# ...                                       ...
# 56254                                    31.0
# 56255                                    82.0
# 56256                                   232.0
# 56257                                    77.0
# 56258                                    15.0
#
#        Beneficiarias BF feminino 25 a 34 anos  \
# 0                                       183.0
# 1                                       170.0
# 2                                       196.0
# 3                                      1290.0
# 4                                       116.0
# ...                                       ...
# 56254                                    66.0
# 56255                                   174.0
# 56256                                   415.0
# 56257                                   108.0
# 56258                                    41.0
#
#        Beneficiarias BF feminino 35 a 39 anos  \
# 0                                        92.0
# 1                                        69.0
# 2                                        85.0
# 3                                       607.0
# 4                                        43.0
# ...                                       ...
# 56254                                    21.0
# 56255                                    48.0
# 56256                                   175.0
# 56257                                    58.0
# 56258                                    13.0
#
#        Beneficiarias BF feminino 40 a 44 anos  \
# 0                                       109.0
# 1                                        69.0
# 2                                        70.0
# 3                                       428.0
# 4                                        33.0
# ...                                       ...
# 56254                                    19.0
# 56255                                    36.0
# 56256                                   166.0
# 56257                                    47.0
# 56258                                    25.0
#
#        Beneficiarias BF feminino 45 a 49 anos  \
# 0                                        70.0
# 1                                        45.0
# 2                                        52.0
# 3                                       285.0
# 4                                        33.0
# ...                                       ...
# 56254                                    10.0
# 56255                                    31.0
# 56256                                   153.0
# 56257                                    36.0
# 56258                                     8.0
#
#        Beneficiarias BF feminino 50 a 54 anos  \
# 0                                        46.0
# 1                                        47.0
# 2                                        26.0
# 3                                       169.0
# 4                                        27.0
# ...                                       ...
# 56254                                    15.0
# 56255                                    33.0
# 56256                                    99.0
# 56257                                    28.0
# 56258                                     5.0
#
#        Beneficiarias BF feminino 55 a 59 anos  \
# 0                                        26.0
# 1                                        22.0
# 2                                        23.0
# 3                                       122.0
# 4                                         9.0
# ...                                       ...
# 56254                                     9.0
# 56255                                    16.0
# 56256                                   104.0
# 56257                                    29.0
# 56258                                    10.0
#
#        Beneficiarias BF feminino 60 a 64 anos  \
# 0                                        14.0
# 1                                         9.0
# 2                                        14.0
# 3                                        75.0
# 4                                         2.0
# ...                                       ...
# 56254                                     2.0
# 56255                                     9.0
# 56256                                    64.0
# 56257                                     7.0
# 56258                                    10.0
#
#        Beneficiarias BF feminino acima de 64 anos
# 0                                             4.0
# 1                                             4.0
# 2                                             5.0
# 3                                            57.0
# 4                                             3.0
# ...                                           ...
# 56254                                         0.0
# 56255                                         2.0
# 56256                                         8.0
# 56257                                         3.0
# 56258                                         1.0
#
# [56259 rows x 19 columns]

# %%
# df_teste['Pessoas beneficiarias BF renda per capita maior meio salario minimo'] = df_teste['Pessoas beneficiarias BF renda per capita maior meio salario minimo'].fillna)
# df_teste['Pessoas beneficiarias BF renda per capita maior meio salario minimo'] = df_teste['Pessoas beneficiarias BF renda per capita maior meio salario minimo'].astype('Int64')
coluna_ignorada = ['Data', 'Municipio']

# 3. Selecionando todas as colunas menos a ignorada
colunas_para_converter = df_teste.columns.difference(coluna_ignorada)

# 4. Aplicando a conversão
df_teste[colunas_para_converter] = df_teste[colunas_para_converter].astype('Int64')
print(df_teste.dtypes)
# Out:
# Municipio                                                                str
# Data                                                                     str
# Pessoas beneficiarias BF em extrema pobreza                            Int64
# Pessoas beneficiarias BF em pobreza                                    Int64
# Pessoas beneficiarias BF em baixa renda                                Int64
# Pessoas beneficiarias BF renda per capita maior meio salario minimo    Int64
# Beneficiarias BF feminino 0 a 3 anos                                   Int64
# Beneficiarias BF feminino 4 a 6 anos                                   Int64
# Beneficiarias BF feminino 7 a 15 anos                                  Int64
# Beneficiarias BF feminino 16 a 17 anos                                 Int64
# Beneficiarias BF feminino 18 a 24 anos                                 Int64
# Beneficiarias BF feminino 25 a 34 anos                                 Int64
# Beneficiarias BF feminino 35 a 39 anos                                 Int64
# Beneficiarias BF feminino 40 a 44 anos                                 Int64
# Beneficiarias BF feminino 45 a 49 anos                                 Int64
# Beneficiarias BF feminino 50 a 54 anos                                 Int64
# Beneficiarias BF feminino 55 a 59 anos                                 Int64
# Beneficiarias BF feminino 60 a 64 anos                                 Int64
# Beneficiarias BF feminino acima de 64 anos                             Int64
# dtype: object

# %%
df_teste
# Out:
#                  Municipio     Data  \
# 0                   ABATIÁ  01/2015
# 1             ADRIANÓPOLIS  01/2015
# 2            AGUDOS DO SUL  01/2015
# 3      ALMIRANTE TAMANDARÉ  01/2015
# 4       ALTAMIRA DO PARANÁ  01/2015
# ...                    ...      ...
# 56254              VIRMOND  12/2025
# 56255             VITORINO  12/2025
# 56256       WENCESLAU BRAZ  12/2025
# 56257               XAMBRÊ  12/2025
# 56258               ÂNGULO  12/2025
#
#        Pessoas beneficiarias BF em extrema pobreza  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 56254                                          NaN
# 56255                                          NaN
# 56256                                          NaN
# 56257                                          NaN
# 56258                                          NaN
#
#        Pessoas beneficiarias BF em pobreza  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 56254                                386.0
# 56255                               1135.0
# 56256                               3489.0
# 56257                               1000.0
# 56258                                311.0
#
#        Pessoas beneficiarias BF em baixa renda  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 56254                                    170.0
# 56255                                    224.0
# 56256                                    611.0
# 56257                                    195.0
# 56258                                     97.0
#
#        Pessoas beneficiarias BF renda per capita maior meio salario minimo  \
# 0                                                   <NA>
# 1                                                   <NA>
# 2                                                   <NA>
# 3                                                   <NA>
# 4                                                   <NA>
# ...                                                  ...
# 56254                                                  0
# 56255                                                  0
# 56256                                                  0
# 56257                                                  0
# 56258                                                  0
#
#        Beneficiarias BF feminino 0 a 3 anos  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 56254                                  31.0
# 56255                                  92.0
# 56256                                 220.0
# 56257                                  73.0
# 56258                                  14.0
#
#        Beneficiarias BF feminino 4 a 6 anos  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 56254                                  24.0
# 56255                                  66.0
# 56256                                 174.0
# 56257                                  61.0
# 56258                                  22.0
#
#        Beneficiarias BF feminino 7 a 15 anos  \
# 0                                      253.0
# 1                                      267.0
# 2                                      267.0
# 3                                     1961.0
# 4                                      118.0
# ...                                      ...
# 56254                                   60.0
# 56255                                  166.0
# 56256                                  427.0
# 56257                                  119.0
# 56258                                   51.0
#
#        Beneficiarias BF feminino 16 a 17 anos  \
# 0                                        75.0
# 1                                        40.0
# 2                                        55.0
# 3                                       379.0
# 4                                        27.0
# ...                                       ...
# 56254                                    10.0
# 56255                                    22.0
# 56256                                    83.0
# 56257                                    15.0
# 56258                                    10.0
#
#        Beneficiarias BF feminino 18 a 24 anos  \
# 0                                       146.0
# 1                                       101.0
# 2                                       135.0
# 3                                       844.0
# 4                                        61.0
# ...                                       ...
# 56254                                    31.0
# 56255                                    82.0
# 56256                                   232.0
# 56257                                    77.0
# 56258                                    15.0
#
#        Beneficiarias BF feminino 25 a 34 anos  \
# 0                                       183.0
# 1                                       170.0
# 2                                       196.0
# 3                                      1290.0
# 4                                       116.0
# ...                                       ...
# 56254                                    66.0
# 56255                                   174.0
# 56256                                   415.0
# 56257                                   108.0
# 56258                                    41.0
#
#        Beneficiarias BF feminino 35 a 39 anos  \
# 0                                        92.0
# 1                                        69.0
# 2                                        85.0
# 3                                       607.0
# 4                                        43.0
# ...                                       ...
# 56254                                    21.0
# 56255                                    48.0
# 56256                                   175.0
# 56257                                    58.0
# 56258                                    13.0
#
#        Beneficiarias BF feminino 40 a 44 anos  \
# 0                                       109.0
# 1                                        69.0
# 2                                        70.0
# 3                                       428.0
# 4                                        33.0
# ...                                       ...
# 56254                                    19.0
# 56255                                    36.0
# 56256                                   166.0
# 56257                                    47.0
# 56258                                    25.0
#
#        Beneficiarias BF feminino 45 a 49 anos  \
# 0                                        70.0
# 1                                        45.0
# 2                                        52.0
# 3                                       285.0
# 4                                        33.0
# ...                                       ...
# 56254                                    10.0
# 56255                                    31.0
# 56256                                   153.0
# 56257                                    36.0
# 56258                                     8.0
#
#        Beneficiarias BF feminino 50 a 54 anos  \
# 0                                        46.0
# 1                                        47.0
# 2                                        26.0
# 3                                       169.0
# 4                                        27.0
# ...                                       ...
# 56254                                    15.0
# 56255                                    33.0
# 56256                                    99.0
# 56257                                    28.0
# 56258                                     5.0
#
#        Beneficiarias BF feminino 55 a 59 anos  \
# 0                                        26.0
# 1                                        22.0
# 2                                        23.0
# 3                                       122.0
# 4                                         9.0
# ...                                       ...
# 56254                                     9.0
# 56255                                    16.0
# 56256                                   104.0
# 56257                                    29.0
# 56258                                    10.0
#
#        Beneficiarias BF feminino 60 a 64 anos  \
# 0                                        14.0
# 1                                         9.0
# 2                                        14.0
# 3                                        75.0
# 4                                         2.0
# ...                                       ...
# 56254                                     2.0
# 56255                                     9.0
# 56256                                    64.0
# 56257                                     7.0
# 56258                                    10.0
#
#        Beneficiarias BF feminino acima de 64 anos      _merge
# 0                                             4.0  right_only
# 1                                             4.0  right_only
# 2                                             5.0  right_only
# 3                                            57.0  right_only
# 4                                             3.0  right_only
# ...                                           ...         ...
# 56254                                         0.0        both
# 56255                                         2.0        both
# 56256                                         8.0        both
# 56257                                         3.0        both
# 56258                                         1.0        both
#
# [56259 rows x 20 columns]
