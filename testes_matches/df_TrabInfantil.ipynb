# %%
import pandas as pd
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine, text
from sshtunnel import SSHTunnelForwarder

#EDITAR AQUI PARA O CAMINHO DAS BASES DE DADOS -- ou fzr automatico
#CAMINHO_BASES = 'C:/utfpr/bd2/Banco-de-Dados-2/bases' #giu
CAMINHO_BASES = '/home/julia/BD2/Datasets' #julia

df_TrabInfantil = pd.read_csv(f'{CAMINHO_BASES}/Familias_Pessoas_TrabInfantil.csv', sep=',', encoding='latin1')

# Index(['Código', 'Unidade Territorial', 'UF', 'Referência',
#        'Quantidade de famílias beneficiárias do Programa Bolsa Família em situação de trabalho infantil',
#        'Quantidade de pessoas beneficiárias do Programa Bolsa Família em situação de trabalho infantil'],
#       dtype='str')

df_TrabInfantil = df_TrabInfantil.drop(columns=['Código', 'UF'])
df_TrabInfantil = df_TrabInfantil.rename(columns={'Referência':'Data', 'Unidade Territorial':'Municipio',
                                                  'Quantidade de famílias beneficiárias do Programa Bolsa Família em situação de trabalho infantil':'Familias BF em situação de trabalho infantil',
                                                  'Quantidade de pessoas beneficiárias do Programa Bolsa Família em situação de trabalho infantil':'Pessoas BF em situação de trabalho infantil'})

# %% [markdown]
# ### Verificando se possui todos os municípios do PR:

# %%
df_teste_mun= df_TrabInfantil['Municipio'].unique().tolist()

df_municipios = pd.read_csv(f'{CAMINHO_BASES}/municipios_pr.csv', sep=',')
df_municipios = df_municipios['nome'].str.upper()

df_municipios = df_municipios.str.replace("D'OESTE", "DOESTE", regex=False)

faltantes_df1 = set(df_teste_mun) - set(df_municipios)
faltantes_df2 = set(df_municipios) - set(df_teste_mun)

print({len(faltantes_df2)})
print({len(faltantes_df1)})
# Out:
# {0}
# {0}
